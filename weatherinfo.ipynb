# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\priyanka'

# %%
os.listdir('C:\\Users\\priyanka')
# Out:
# ['.anaconda',
#  '.android',
#  '.bash_history',
#  '.conda',
#  '.condarc',
#  '.config',
#  '.cufflinks',
#  '.git',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.packettracer',
#  '3D Objects',
#  'ampmoddemod.m',
#  'AppData',
#  'Application Data',
#  'Autodesk',
#  'Cisco Packet Tracer 7.3.0',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'exp2.m',
#  'Favorites',
#  'harshal ke lectures.ipynb',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'mat1.m',
#  'MicrosoftEdgeBackups',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'New folder (2)',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{ff82260b-c743-11ec-ae09-fc7034bf36dd}.TM.blf',
#  'NTUSER.DAT{ff82260b-c743-11ec-ae09-fc7034bf36dd}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{ff82260b-c743-11ec-ae09-fc7034bf36dd}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Pictures',
#  'PrintHood',
#  'priyanka.sce',
#  'priyanka1.sce',
#  'Recent',
#  'Saved Games',
#  'seaborn-data',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'Templates',
#  'Test.csv',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'Videos']

# %%
weather = pd.read_csv('Test.csv')

# %%
weather.head()
# Out:
#           date_time is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  18-05-2017 00:00       None                 73.0      63.0         1.0
# 1  18-05-2017 00:00       None                251.0      63.0         1.0
# 2  18-05-2017 00:00       None                 75.0      56.0         1.0
# 3  18-05-2017 01:00       None                 98.0      56.0         1.0
# 4  18-05-2017 01:00       None                283.0      56.0         1.0
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0            27.0                  4.0        4.0       285.15       0.0
# 1            27.0                  4.0        4.0       285.15       0.0
# 2             0.0                  1.0        1.0       285.15       0.0
# 3           351.0                  2.0        2.0       284.79       0.0
# 4           351.0                  1.0        1.0       284.79       0.0
#
#    snow_p_h  clouds_all weather_type      weather_description
# 0       0.0        90.0         Rain            moderate rain
# 1       0.0        90.0         Mist                     mist
# 2       0.0        90.0      Drizzle  light intensity drizzle
# 3       0.0        90.0         Rain     heavy intensity rain
# 4       0.0        90.0         Mist                     mist

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14454 entries, 0 to 14453
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date_time            199 non-null    object
#  1   is_holiday           199 non-null    object
#  2   air_pollution_index  199 non-null    float64
#  3   humidity             199 non-null    float64
#  4   wind_speed           199 non-null    float64
#  5   wind_direction       199 non-null    float64
#  6   visibility_in_miles  199 non-null    float64
#  7   dew_point            199 non-null    float64
#  8   temperature          199 non-null    float64
#  9   rain_p_h             199 non-null    float64
#  10  snow_p_h             199 non-null    float64
#  11  clouds_all           199 non-null    float64
#  12  weather_type         199 non-null    object
#  13  weather_description  199 non-null    object
# dtypes: float64(10), object(4)
# memory usage: 1.5+ MB

# %%
sns.barplot(x=weather['humidity'], y=weather['temperature'])
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='temperature'>

# %%
sns.displot(x=weather['humidity'])

# %%
sns.displot(x=weather['humidity'], kde=False, rug=True);

# %%
sns.displot(x=weather['humidity'], kde=True, rug=False);

# %%
sns.jointplot(x=weather['humidity'], y=weather['temperature'])

# %%
sns.jointplot(x=weather['humidity'], y=weather['temperature'], kind='hex')

# %%
sns.jointplot(x=weather['humidity'], y=weather['temperature'], hue=weather['humidity'])

# %%
sns.jointplot(x=weather['humidity'], y=weather['temperature'], hue=weather['temperature'])

# %%
sns.jointplot(x=weather['humidity'], y=weather['temperature'], kind='kde')

# %%
sns.pairplot(weather[['humidity', 'temperature', 'air_pollution_index']])

# %%
sns.stripplot(x=weather['weather_type'], y=weather['temperature'])
# Out:
# <AxesSubplot:xlabel='weather_type', ylabel='temperature'>

# %%
sns.swarmplot(x=weather['humidity'], y=weather['temperature'], s=0.9)
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='temperature'>

# %%
sns.boxplot(x=weather['humidity'], y=weather['temperature'], hue=weather['weather_type'])
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='temperature'>

# %%
sns.barplot(x=weather['humidity'], y=weather['temperature'], hue=weather['weather_type'])
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='temperature'>

# %%
sns.countplot(x=weather['weather_type'])
# Out:
# <AxesSubplot:xlabel='weather_type', ylabel='count'>

# %%
sns.pointplot(x=weather['humidity'], y=weather['temperature'], hue=weather['weather_type'])
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='temperature'>

# %%
sns.lmplot(x="humidity", y="temperature", hue="weather_type", data=weather)
